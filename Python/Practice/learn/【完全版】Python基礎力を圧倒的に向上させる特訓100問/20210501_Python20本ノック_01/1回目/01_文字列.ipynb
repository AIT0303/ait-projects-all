# %%
## 文字列の操作

### 問題3 文字列の代入(format/f-strings)
以下の文章の「〇〇」に対して`.format()`とf-stringsを使って代入しましょう。  
「私は〇〇です。〇〇出身です。」

（目安時間：1分）

**解答**
a = tanaka
b = 広島
f"私は{a}です。{b}出身です。"
# Out:
#   Cell In[1], line 4
#     以下の文章の「〇〇」に対して`.format()`とf-stringsを使って代入しましょう。
#           ^
# SyntaxError: invalid character '「' (U+300C)

# %%
name = "tanaka"
birthplace = "広島"
f'私は{name}です。{birthplace}出身です。'
# Out:
# '私はtanakaです。広島出身です。'

# %% [markdown]
# ### 問題4 エスケープ文字
#
# 次の文字列を句読点で改行しましょう。
#
# 「いつもの帰り道とは違うルートで帰ってみようかな。迷子にならないか心配だけど。」
#
# ↓
#
# 「いつもの帰り道とは違うルートで帰ってみようかな。
# 迷子にならないか心配だけど。」
#
# （目安時間：1分）
#
# **解答**

# %%
s= "いつもの帰り道とは違うルートで帰ってみようかな。\n迷子にならないか心配だけど。"
print(s)
# Out:
# いつもの帰り道とは違うルートで帰ってみようかな。
# 迷子にならないか心配だけど。

# %% [markdown]
# ### 問題5 書式化
#
# `16.0`という値を次の書式で表示しましょう。
#
# - 符号付き10進数
# - 符号付き16進数
# - 10進浮動小数点
#
# （目安時間：1分）
#
# **解答**

# %%
a = 16
print("%d"%(a))
# Out:
# 16

# %%
a= 15
print("%x"%(a))
print("%f"%(a))
# Out:
# f
# 15.000000

# %% [markdown]
# ### 問題6 大文字・小文字への変換
#
# 以下の文字列を小文字→大文字、大文字→小文字への変換を行いましょう
#
# - `'hello'`
# - `'WORLD'`
#
# （目安時間：1分）
#
# **解答**

# %%
a= "hello"
print(a.upper())
print(a.lower())
# Out:
# HELLO
# hello

# %% [markdown]
# ### 問題7 分割
# こちらの文章を改行部分で分割しましょう。
#
# 「こんにちは。\n私はAIのロボットです。」
#
# （目安時間：1分）
#
# **解答**

# %%
a = "こんにちは。\n私はAIのロボットです。"
print(a.split("\n"))
# Out:
# ['こんにちは。', '私はAIのロボットです。']

# %% [markdown]
# ### 問題8 結合
# 以下のリスト内に入っている文字列を結合して一つの文にしましょう。
#
# ```python
# messages = ['こんにちは。', '私はAIのロボットです。']
# ```
#
# （目安時間：1分）
#
# **解答**

# %%
messages = ['こんにちは。', '私はAIのロボットです。']
"".join(messages)
# Out:
# 'こんにちは。私はAIのロボットです。'

# %% [markdown]
# ### 問題9 空白除去
# 文のはじめと最後にある空白を除去しましょう。
#
# 「　いつも食べるここのケーキはとても美味しいね。　」
#
# ※全角スペースです
#
#
# （目安時間：1分）
#
# **解答**
# s= "「　いつも食べるここのケーキはとても美味しいね。　」"

# %%
s= "               　いつも食べるここのケーキはとても美味しいね。　              "

print(s.strip())
# Out:
# いつも食べるここのケーキはとても美味しいね。

# %% [markdown]
# ### 問題10 置換
# 以下の文の「晴れ」を「雨」に置換してください。
#
# 「今日は晴れですね。」
# （目安時間：1分）
#
# **解答**

# %%
a = "今日は晴れですね。"
a.replace("晴れ","雨")
# Out:
# '今日は雨ですね。'

# %% [markdown]
# ### 問題11 文字列検索
# 以下のフレーズの中から「夜空」を検索し、その位置を出力しましょう。
#
# 「今日はとても夜空が綺麗だ。」
#
#
# （目安時間：1分）
#
# **解答**

# %%
a= "今日はとても夜空が綺麗だ。"
a.find("は")
# Out:
# 2

# %% [markdown]
# ### 問題12 型変換
# 以下のデータ型を文字列型に変換しましょう。
#
# - int:`x = 1`
# - float: `x = 1.52`
# - list: `x = [1, 2, 3]`
# - dict: `x = dict(name='john', birth='US')`
#
# （目安時間：2分）
#
# **解答**

# %%
x = 1
print(str(x))
# Out:
# 1

# %% [markdown]
# ### 問題13 包含関係
# 以下の文字列Aが文字列Bに含まれているか確認しましょう。
#
# - A: `'sba'`, B: `'gasba'`
# - A: `'xdh'`, B: `'orweit'`
#
# （目安時間：1分）
#
# **解答**

# %%
A= 'sbadf'
B= 'gasba'
A in B
# Out:
# False

# %%
A= 'xdh'
B= 'orweit'
A in B
# Out:
# False
