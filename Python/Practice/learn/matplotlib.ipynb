# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
plt.plot([0,2,1,3])
plt.show()

# %%
import pandas as pd
data = [[60,65,66],
       [80,85,88],
       [100,100,100]]

columns= ["国語","数学","英語"]
index = ["弘輝","柚香","きいちゃん"]
df = pd.DataFrame(data, columns=columns, index=index)
df
# Out:
#         国語   数学   英語
# 弘輝      60   65   66
# 柚香      80   85   88
# きいちゃん  100  100  100

# %%
df.columns
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.items
# Out:
# <bound method DataFrame.items of      0    1    2
# 0   60   65   66
# 1   80   85   88
# 2  100  100  100>

# %%
df.columns= ["国語","数学","英語"]
df.index = ["弘輝","柚香","きいちゃん"]
df
# Out:
#         国語   数学   英語
# 弘輝      60   65   66
# 柚香      80   85   88
# きいちゃん  100  100  100

# %%
df
# Out:
#         国語   数学   英語
# 弘輝      60   65   66
# 柚香      80   85   88
# きいちゃん  100  100  100

# %%
df_test = pd.read_csv("test.csv")
df_test
# Out:
#    名前   国語  数学  英語  学生番号
# 0  A太   83  89  76  A001
# 1  B介   66  93  75  B001
# 2  C子  100  84  96  B002
# 3  D郎   60  73  40  A002
# 4  E美   92  62  84  C001
# 5  F菜   96  92  94  C002

# %%
df_idx = pd.read_csv("test.csv",index_col=0, header=None)

# %%
df_idx.head(

)
# Out:
#       1   2   3     4
# 0
# 名前   国語  数学  英語  学生番号
# A太   83  89  76  A001
# B介   66  93  75  B001
# C子  100  84  96  B002
# D郎   60  73  40  A002

# %%
df
# Out:
#         国語   数学   英語
# 弘輝      60   65   66
# 柚香      80   85   88
# きいちゃん  100  100  100

# %%
df.columns
# Out:
# Index(['国語', '数学', '英語'], dtype='object')

# %%
df.index
# Out:
# Index(['弘輝', '柚香', 'きいちゃん'], dtype='object')

# %%
len(df)
# Out:
# 3

# %%
df["国語"]
# Out:
# 弘輝        60
# 柚香        80
# きいちゃん    100
# Name: 国語, dtype: int64

# %%
df.loc["弘輝"]
# Out:
# 国語    60
# 数学    65
# 英語    66
# Name: 弘輝, dtype: int64
